# %%
#collapse-hide
import sys
import pyodbc 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from collections import Counter
from sklearn.decomposition import PCA
from adjustText import adjust_text
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook')
plt.rcParams["font.family"] = "sans-serif"
PLOTS_DIR = 'images'
# %matplotlib inline

# %%
#collapse-hide

periodid = 151
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=HUM1006903\SQLEXPRESS;'
                      'Database=oda_20201103;'
                      #'Database=oda;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()

sql_query = pd.read_sql_query('SELECT \
        oda.dbo.Afstemning.id AS afstemning, \
        oda.dbo.Sag.periodeid, \
        oda.dbo.Periode.titel AS periode, \
        oda.dbo.Sag.titel AS titel, \
        oda.dbo.Sag.resume, \
        oda.dbo.Afstemning.konklusion, \
        oda.dbo.Sagstrin.dato, \
        oda.dbo.Stemme.typeid AS stemme, \
        oda.dbo.Aktør.fornavn, \
        oda.dbo.Aktør.efternavn, \
        oda.dbo.Aktør.biografi \
    FROM oda.dbo.Afstemning \
    JOIN oda.dbo.Stemme ON oda.dbo.Afstemning.id = oda.dbo.Stemme.afstemningid \
    JOIN oda.dbo.Aktør ON oda.dbo.Aktør.id = oda.dbo.Stemme.aktørid \
    JOIN oda.dbo.Sagstrin ON oda.dbo.Sagstrin.id = oda.dbo.Afstemning.sagstrinid \
    JOIN oda.dbo.Sag ON oda.dbo.Sag.id = oda.dbo.Sagstrin.sagid \
    JOIN oda.dbo.Periode ON oda.dbo.Sag.periodeid = oda.dbo.Periode.id \
    WHERE oda.dbo.Sag.periodeid='+str(periodid)+';', conn)

sql_query.head()
# Out:
#    afstemning  periodeid  periode  \
# 0        7165        151  2019-20
# 1        7165        151  2019-20
# 2        7165        151  2019-20
# 3        7165        151  2019-20
# 4        7165        151  2019-20
#
#                                                titel  \
# 0  Forslag til folketingsbeslutning om danske mil...
# 1  Forslag til folketingsbeslutning om danske mil...
# 2  Forslag til folketingsbeslutning om danske mil...
# 3  Forslag til folketingsbeslutning om danske mil...
# 4  Forslag til folketingsbeslutning om danske mil...
#
#                                               resume  \
# 0  Med folketingsbeslutningen får regeringen Folk...
# 1  Med folketingsbeslutningen får regeringen Folk...
# 2  Med folketingsbeslutningen får regeringen Folk...
# 3  Med folketingsbeslutningen får regeringen Folk...
# 4  Med folketingsbeslutningen får regeringen Folk...
#
#                                           konklusion       dato  stemme  \
# 0  Forslaget blev vedtaget. For stemte 106 (S, V,... 2019-10-24       1
# 1  Forslaget blev vedtaget. For stemte 106 (S, V,... 2019-10-24       1
# 2  Forslaget blev vedtaget. For stemte 106 (S, V,... 2019-10-24       1
# 3  Forslaget blev vedtaget. For stemte 106 (S, V,... 2019-10-24       1
# 4  Forslaget blev vedtaget. For stemte 106 (S, V,... 2019-10-24       1
#
#          fornavn        efternavn  \
# 0         Erling         Bonnesen
# 1         Morten          Bødskov
# 2           Bent          Bøgsted
# 3        Lennart  Damsbo-Andersen
# 4  Louise Schack           Elholm
#
#                                             biografi
# 0  <member><url>/medlemmer/mf/e/erling-bonnesen</...
# 1  <member><url>/medlemmer/mf/m/morten-boedskov</...
# 2  <member><url>/medlemmer/mf/b/bent-boegsted</ur...
# 3  <member><url>/medlemmer/mf/l/lennart-damsbo-an...
# 4  <member><url>/medlemmer/mf/l/louise-schack-elh...

# %%
#collapse-hide
party = []
for bio_string in sql_query['biografi'].values:
    try:
        root = ET.fromstring(bio_string)
        for child in root.findall("./party"):
            party.append(child.text)
    except Exception as e:
        party.append(None)
        continue
sql_query['party'] = party
#sql_query.party.unique()

# %%
#collapse-hide

sql_query['navn'] = sql_query[['fornavn', 'efternavn']].agg(' '.join, axis=1)

# %%
#collapse-hide

df = sql_query[['afstemning', 'titel', 'resume', 'konklusion', 'navn', 'party', 'stemme']]
df['stemme'].replace(to_replace=2, value=-1, inplace=True)
df['stemme'].replace(to_replace=4, value=0, inplace=True)
df.tail()
# Out:
#        afstemning                                              titel resume  \
# 57812        7490  Folketinget konstaterer, at det aftalte loft o...
# 57813        7490  Folketinget konstaterer, at det aftalte loft o...
# 57814        7490  Folketinget konstaterer, at det aftalte loft o...
# 57815        7490  Folketinget konstaterer, at det aftalte loft o...
# 57816        7490  Folketinget konstaterer, at det aftalte loft o...
#
#                                               konklusion  \
# 57812  Forslaget blev vedtaget. For stemte 54 (S, RV,...
# 57813  Forslaget blev vedtaget. For stemte 54 (S, RV,...
# 57814  Forslaget blev vedtaget. For stemte 54 (S, RV,...
# 57815  Forslaget blev vedtaget. For stemte 54 (S, RV,...
# 57816  Forslaget blev vedtaget. For stemte 54 (S, RV,...
#
#                         navn                        party  stemme
# 57812       Birgitte Bergman  Det Konservative Folkeparti       0
# 57813          Birgitte Vind            Socialdemokratiet       0
# 57814       Pernille Vermund               Nye Borgerlige       0
# 57815  Theresa Berg Andersen      Socialistisk Folkeparti       0
# 57816            Ruben Kidde             Radikale Venstre       0

# %%
#show
Counter(df.stemme)
# Out:
# Counter({1: 22567, -1: 11244, 3: 20853, 0: 3153})

# %%
#collapse-hide
#Vi kan også prøve at kigge på løsgængerne stemmeadfærd:
s = []
for lg in df.navn.unique():
    #print(lg, Counter(sql_query[sql_query.navn == lg].stemme)[3])
    s.append((lg, Counter(sql_query[sql_query.navn == lg].stemme)[3]))
sorted_fravaer = sorted(s, reverse=True, key=lambda tup: tup[1])
sorted_fravaer
#som viser at Uffe Elbæk og Simon Emil Ammitzbøll-Bille (begge i midten af x-aksen) været fraværende ved hhv 71% og 84% af alle registrerede afstemninger i folketingssalen (da der er møde- og stemmepligt, og de to næppe har lavet clearingsaftaler, er det måske en sag der er værd at undersøge nærmere). Sikandar Siddique (på venstre side af x-aksen tæt på SF) derimod deltager flittigt i afstemningerne.
# Out:
# [('Mette Frederiksen', 283),
#  ('Claus Hjort Frederiksen', 280),
#  ('Edmund Joensen', 280),
#  ('Sjúrður Skaale', 278),
#  ('Aaja Chemnitz Larsen', 278),
#  ('Morten Østergaard', 276),
#  ('Simon Emil Ammitzbøll-Bille', 272),
#  ('Kristian Jensen', 262),
#  ('Pia Kjærsgaard', 261),
#  ('Pia Olsen Dyhr', 252),
#  ('Lars Løkke Rasmussen', 246),
#  ('Dan Jørgensen', 237),
#  ('Hans Christian Schmidt', 235),
#  ('Nicolai Wammen', 232),
#  ('Magnus Heunicke', 230),
#  ('Aki-Matilda Høegh-Dam', 230),
#  ('Uffe Elbæk', 229),
#  ('Pernille Rosenkrantz-Theil', 228),
#  ('Jakob Ellemann-Jensen', 225),
#  ('Henrik Dam Kristensen', 216),
#  ('Mogens Jensen', 206),
#  ('Jacob Jensen', 204),
#  ('Ane Halsboe-Jørgensen', 204),
#  ('Astrid Krag', 202),
#  ('Søren Søndergaard', 201),
#  ('Martin Lidegaard', 199),
#  ('Pernille Skipper', 199),
#  ('Jacob Mark', 197),
#  ('Rasmus Prehn', 190),
#  ('Ina Strøjer-Schmidt', 186),
#  ('Eva Kjer Hansen', 184),
#  ('Marcus Knuth', 183),
#  ('Jens Rohde', 182),
#  ('Brigitte Klintskov Jerkel', 180),
#  ('Søren Espersen', 179),
#  ('Troels Lund Poulsen', 177),
#  ('Eva Flyvholm', 175),
#  ('Lea Wermelin', 171),
#  ('Britt Bager', 171),
#  ('Mai Mercado', 170),
#  ('Karsten Lauritzen', 168),
#  ('Sofie Carsten Nielsen', 166),
#  ('Søren Pape Poulsen', 165),
#  ('Nick Hækkerup', 164),
#  ('Mette Abildgaard', 164),
#  ('Rune Lund', 162),
#  ('Andreas Steenberg', 161),
#  ('Flemming Møller Mortensen', 159),
#  ('Kristian Thulesen Dahl', 152),
#  ('Peter Skaarup', 152),
#  ('Bertel Haarder', 147),
#  ('Kaare Dybvad Bek', 147),
#  ('Morten Messerschmidt', 145),
#  ('Benny Engelbrecht', 142),
#  ('Simon Kollerup', 139),
#  ('Pernille Vermund', 137),
#  ('Henning Hyllested', 136),
#  ('Fatma Øktem', 135),
#  ('Peder Hvelplund', 135),
#  ('Thomas Jensen', 135),
#  ('Jane Heitmann', 135),
#  ('Alex Vanopslagh', 134),
#  ('Morten Bødskov', 130),
#  ('Kim Valentin', 128),
#  ('Ida Auken', 127),
#  ('Lars Christian Lilleholt', 126),
#  ('Naser Khader', 126),
#  ('René Christensen', 126),
#  ('Sophie Løhde', 125),
#  ('Marianne Jelved', 125),
#  ('Per Larsen', 121),
#  ('Trine Bramsen', 120),
#  ('Peter Hummelgaard', 120),
#  ('Karsten Hønge', 119),
#  ('Anne Sophie Callesen', 118),
#  ('Mette Thiesen', 115),
#  ('Rosa Lund', 114),
#  ('Michael Aastrup Jensen', 113),
#  ('Karen Ellemann', 113),
#  ('Susanne Zimmer', 113),
#  ('Erling Bonnesen', 112),
#  ('Katarina Ammitzbøll', 112),
#  ('Hans Andersen', 111),
#  ('Christian Rabjerg Madsen', 111),
#  ('Carsten Kissmeyer', 111),
#  ('Mattias Tesfaye', 110),
#  ('Annette Lind', 109),
#  ('Anne Valentina Berthelsen', 109),
#  ('Samira Nawa', 108),
#  ('Peter Seier Christensen', 107),
#  ('Inger Støjberg', 105),
#  ('Lennart Damsbo-Andersen', 104),
#  ('Leif Lahn Jensen', 103),
#  ('Rasmus Nordqvist', 103),
#  ('Jesper Petersen', 102),
#  ('Christian Juhl', 102),
#  ('Jan E. Jørgensen', 99),
#  ('Torsten Gejl', 99),
#  ('Kristian Pihl Lorentzen', 98),
#  ('Jens Henrik Thulesen Dahl', 97),
#  ('Ellen Trane Nørby', 95),
#  ('Rasmus Helveg Petersen', 94),
#  ('Jan Johansen', 91),
#  ('Trine Torp', 89),
#  ('Jette Gottlieb', 89),
#  ('Charlotte Broman Mølbæk', 89),
#  ('Troels Ravn', 88),
#  ('Mads Fuglede', 87),
#  ('Preben Bang Henriksen', 86),
#  ('Signe Munk', 86),
#  ('Christoffer Aagaard Melson', 85),
#  ('Hans Kristian Skibby', 84),
#  ('Martin Geertsen', 84),
#  ('Lars Aslan Rasmussen', 84),
#  ('Søren Egge Rasmussen', 84),
#  ('Dennis Flydtkjær', 83),
#  ('Jeppe Bruus', 83),
#  ('Tommy Ahlers', 81),
#  ('Karina Lorentzen Dehnhardt', 81),
#  ('Rasmus Stoklund', 81),
#  ('Marie Bjerre', 80),
#  ('Ulla Tørnæs', 76),
#  ('Orla Østerby', 75),
#  ('Kasper Roug', 74),
#  ('Bjarne Laustsen', 72),
#  ('Kristian Hegaard', 72),
#  ('Lars Boje Mathiesen', 71),
#  ('Rasmus Jarlov', 70),
#  ('Bjørn Brandenborg', 68),
#  ('Mette Gjerskov', 66),
#  ('Mette Hjermind Dencker', 66),
#  ('Marlene Ambo-Rasmussen', 65),
#  ('Heidi Bank', 62),
#  ('Birgitte Bergman', 62),
#  ('Lisbeth Bech-Nielsen', 62),
#  ('Mai Villadsen', 61),
#  ('Kathrine Olldag', 60),
#  ('Sikandar Siddique', 59),
#  ('Liselott Blixt', 57),
#  ('Rasmus Horn Langhoff', 55),
#  ('Daniel Toft Jakobsen', 55),
#  ('Anders Kronborg', 52),
#  ('Peter Juel-Jensen', 52),
#  ('Orla Hav', 51),
#  ('Stinus Lindgreen', 51),
#  ('Bent Bøgsted', 50),
#  ('Kirsten Normann Andersen', 50),
#  ('Louise Schack Elholm', 48),
#  ('Niels Flemming Hansen', 47),
#  ('Karina Adsbøl', 45),
#  ('Anni Matthiesen', 45),
#  ('Carl Valentin', 45),
#  ('Victoria Velasquez', 43),
#  ('Stén Knuth', 41),
#  ('Julie Skovsby', 40),
#  ('Nils Sjøberg', 40),
#  ('Lise Bech', 39),
#  ('Birgitte Vind', 38),
#  ('Torsten Schack Pedersen', 37),
#  ('Henrik Møller', 36),
#  ('Halime Oguz', 35),
#  ('Astrid Carøe', 34),
#  ('Camilla Fabricius', 34),
#  ('Anne Paulin', 34),
#  ('Jens Joel', 32),
#  ('Pernille Bendixen', 31),
#  ('Jakob Sølvhøj', 30),
#  ('Malte Larsen', 30),
#  ('Kasper Sand Kjær', 27),
#  ('Mona Juul', 26),
#  ('Anne Honoré Østergaard', 25),
#  ('Tanja Larsson', 23),
#  ('Theresa Berg Andersen', 23),
#  ('Alex Ahrendtsen', 22),
#  ('Katrine Robsøe', 19),
#  ('Henrik Dahl', 18),
#  ('Ole Birk Olesen', 17),
#  ('Zenia Stampe', 15),
#  ('Thomas Danielsen', 12),
#  ('Ruben Kidde', 11),
#  ('Marie Krarup', 10),
#  ('Gitte Willumsen', 9),
#  ('Barbara Gaardlykke Apol', 5),
#  ('Balder Mørk Andersen', 3),
#  ('Morten Dahlin', 2),
#  ('Mira Issa Bloch', 2),
#  ('Dorthe Hindborg', 1),
#  ('Susanne Eilersen', 0),
#  ('Carsten Kudsk', 0),
#  ('Anna Brændemose', 0),
#  ('Anders G. Christensen', 0),
#  ('Hanne Bjørn-Klausen', 0)]
